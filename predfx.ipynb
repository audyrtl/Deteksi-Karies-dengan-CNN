# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import cv2
from google.colab import drive
import pandas as pd
from PIL import Image
import seaborn as sns
from datetime import datetime

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BASE_DIR = '/content/drive/MyDrive/TA/dt2'
MODEL_PATH = os.path.join(BASE_DIR, 'hasil/hierarchical_final_model.h5')  # Model terbaik
IMG_SIZE = 224

# Threshold untuk klasifikasi (bisa di-adjust)
CONFIDENCE_THRESHOLD = 0.5

# %%
def load_trained_model(model_path):
    """
    Load model yang sudah dilatih
    """
    try:
        model = load_model(model_path)
        print(f"✅ Model berhasil dimuat dari: {model_path}")
        print(f"📊 Model input shape: {model.input_shape}")
        return model
    except Exception as e:
        print(f"❌ Error loading model: {e}")
        return None

# %%
# Load model
model = load_trained_model(MODEL_PATH)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model berhasil dimuat dari: /content/drive/MyDrive/TA/dt2/hasil/hierarchical_final_model.h5
# 📊 Model input shape: (None, 224, 224, 3)

# %%
def preprocess_image_for_prediction(img_path, target_size=(224, 224)):
    """
    Preprocess gambar untuk prediksi (sama seperti training)
    """
    try:
        # Load image
        if isinstance(img_path, str):
            # Jika input adalah path file
            img = cv2.imread(img_path)
            if img is None:
                print(f"❌ Tidak bisa membaca gambar: {img_path}")
                return None
        else:
            # Jika input sudah berupa array
            img = img_path

        # Convert BGR to RGB (OpenCV uses BGR)
        if len(img.shape) == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Resize ke ukuran yang diharapkan model
        img_resized = cv2.resize(img, target_size)

        # Normalize ke range [0,1] (sama seperti training)
        img_normalized = img_resized.astype('float32') / 255.0

        # Add batch dimension
        img_batch = np.expand_dims(img_normalized, axis=0)

        return img_batch, img_resized

    except Exception as e:
        print(f"❌ Error preprocessing image: {e}")
        return None, None

# %%
def predict_single_image(model, img_path, show_image=True):
    """
    Prediksi untuk satu gambar
    """
    # Preprocess image
    img_processed, img_display = preprocess_image_for_prediction(img_path)

    if img_processed is None:
        return None

    # Prediksi
    prediction_prob = model.predict(img_processed, verbose=0)[0][0]

    # Klasifikasi berdasarkan threshold
    prediction_class = "Karies" if prediction_prob > CONFIDENCE_THRESHOLD else "Sehat"
    confidence = prediction_prob if prediction_prob > 0.5 else (1 - prediction_prob)

    # Hasil prediksi
    result = {
        'image_path': img_path,
        'prediction_class': prediction_class,
        'probability_karies': prediction_prob,
        'probability_sehat': 1 - prediction_prob,
        'confidence': confidence,
        'confidence_percentage': confidence * 100
    }

    # Tampilkan hasil
    if show_image and img_display is not None:
        plt.figure(figsize=(8, 6))
        plt.imshow(img_display)
        plt.title(f'Prediksi: {prediction_class}\n' +
                 f'Confidence: {confidence:.2%}\n' +
                 f'Prob Karies: {prediction_prob:.3f} | Prob Sehat: {1-prediction_prob:.3f}')
        plt.axis('off')

        # Color coding untuk hasil
        if prediction_class == "Karies":
            plt.gca().add_patch(plt.Rectangle((0, 0), img_display.shape[1], img_display.shape[0],
                                            fill=False, edgecolor='red', linewidth=5))
        else:
            plt.gca().add_patch(plt.Rectangle((0, 0), img_display.shape[1], img_display.shape[0],
                                            fill=False, edgecolor='green', linewidth=5))
        plt.show()

    return result

# %% [markdown]
# # batch

# %%
def predict_batch_images(model, image_folder, save_results=True):
    """
    Prediksi untuk multiple images dalam folder
    """
    # Supported image extensions
    valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')

    # Get all image files
    image_files = []
    for ext in valid_extensions:
        image_files.extend([f for f in os.listdir(image_folder) if f.lower().endswith(ext)])

    if not image_files:
        print("❌ Tidak ada gambar ditemukan dalam folder!")
        return None

    print(f"🔍 Ditemukan {len(image_files)} gambar untuk diprediksi...")

    results = []

    # Process each image
    for i, img_file in enumerate(image_files):
        img_path = os.path.join(image_folder, img_file)
        print(f"📷 Processing {i+1}/{len(image_files)}: {img_file}")

        result = predict_single_image(model, img_path, show_image=False)
        if result:
            result['filename'] = img_file
            results.append(result)

    # Convert to DataFrame for easy analysis
    df_results = pd.DataFrame(results)

    # Summary statistics
    print(f"\n📊 RINGKASAN HASIL PREDIKSI:")
    print(f"Total gambar: {len(results)}")
    print(f"Prediksi Karies: {sum(1 for r in results if r['prediction_class'] == 'Karies')}")
    print(f"Prediksi Sehat: {sum(1 for r in results if r['prediction_class'] == 'Sehat')}")
    print(f"Confidence rata-rata: {np.mean([r['confidence'] for r in results]):.2%}")

    # Save results
    if save_results:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        results_path = os.path.join(BASE_DIR, f'hasil_prediksi_{timestamp}.csv')
        df_results.to_csv(results_path, index=False)
        print(f"💾 Hasil disimpan ke: {results_path}")

    return df_results

# %%
def visualize_batch_results(df_results, max_images=12):
    """
    Visualisasi hasil prediksi batch
    """
    if df_results is None or len(df_results) == 0:
        print("❌ Tidak ada data untuk divisualisasi!")
        return

    # Limit number of images to display
    display_df = df_results.head(max_images)

    # Calculate grid size
    n_images = len(display_df)
    cols = min(4, n_images)
    rows = (n_images + cols - 1) // cols

    fig, axes = plt.subplots(rows, cols, figsize=(15, 4*rows))
    if rows == 1:
        axes = [axes] if cols == 1 else axes
    else:
        axes = axes.flatten()

    for i, (_, row) in enumerate(display_df.iterrows()):
        if i >= len(axes):
            break

        # Load and display image
        img_path = row['image_path']
        img = cv2.imread(img_path)
        if img is not None:
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img_resized = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))

            axes[i].imshow(img_resized)

            # Title with prediction info
            title = f"{row['filename']}\n{row['prediction_class']} ({row['confidence_percentage']:.1f}%)"
            color = 'red' if row['prediction_class'] == 'Karies' else 'green'
            axes[i].set_title(title, color=color, fontweight='bold')
            axes[i].axis('off')

    # Hide unused subplots
    for i in range(n_images, len(axes)):
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

    # Summary plot
    plt.figure(figsize=(12, 4))

    # Pie chart of predictions
    plt.subplot(1, 3, 1)
    prediction_counts = df_results['prediction_class'].value_counts()

    # Pastikan warna sesuai dengan label: Merah untuk Karies, Hijau untuk Sehat
    colors = []
    for label in prediction_counts.index:
        if label == 'Karies':
            colors.append('red')  # Merah untuk Karies
        else:  # Sehat
            colors.append('green')  # Hijau untuk Sehat

    plt.pie(prediction_counts.values, labels=prediction_counts.index, autopct='%1.1f%%', colors=colors)
    plt.title('Distribusi Prediksi')

    plt.tight_layout()
    plt.show()

# %%
def advanced_prediction_analysis(model, img_path):
    """
    Analisis prediksi yang lebih detail dengan confidence intervals
    """
    # Multiple predictions with different preprocessing
    predictions = []

    # Original prediction
    result = predict_single_image(model, img_path, show_image=False)
    if result:
        predictions.append(result['probability_karies'])

    # Test with slight variations (Test Time Augmentation)
    img = cv2.imread(img_path)
    if img is not None:
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Slight rotations
        for angle in [-5, 0, 5]:
            center = (img_rgb.shape[1]//2, img_rgb.shape[0]//2)
            rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
            rotated = cv2.warpAffine(img_rgb, rotation_matrix, (img_rgb.shape[1], img_rgb.shape[0]))

            img_processed, _ = preprocess_image_for_prediction(rotated)
            if img_processed is not None:
                pred_prob = model.predict(img_processed, verbose=0)[0][0]
                predictions.append(pred_prob)

        # Brightness variations
        for brightness in [0.9, 1.0, 1.1]:
            bright_img = np.clip(img_rgb * brightness, 0, 255).astype(np.uint8)
            img_processed, _ = preprocess_image_for_prediction(bright_img)
            if img_processed is not None:
                pred_prob = model.predict(img_processed, verbose=0)[0][0]
                predictions.append(pred_prob)

    # Calculate statistics
    mean_prob = np.mean(predictions)
    std_prob = np.std(predictions)
    confidence_interval = (mean_prob - 1.96*std_prob, mean_prob + 1.96*std_prob)

    # Final prediction
    final_class = "Karies" if mean_prob > CONFIDENCE_THRESHOLD else "Sehat"
    uncertainty = std_prob

    print(f"🔬 ANALISIS PREDIKSI LANJUTAN:")
    print(f"📊 Rata-rata probabilitas karies: {mean_prob:.3f}")
    print(f"📊 Standard deviasi: {std_prob:.3f}")
    print(f"📊 Confidence interval 95%: ({confidence_interval[0]:.3f}, {confidence_interval[1]:.3f})")
    print(f"📊 Uncertainty score: {uncertainty:.3f}")
    print(f"🎯 Prediksi final: {final_class}")

    if uncertainty > 0.1:
        print("⚠️  High uncertainty - sebaiknya konsultasi dengan dokter")
    elif uncertainty > 0.05:
        print("⚠️  Moderate uncertainty - perlu verifikasi tambahan")
    else:
        print("✅ Low uncertainty - prediksi cukup confident")

    return {
        'mean_probability': mean_prob,
        'std_probability': std_prob,
        'confidence_interval': confidence_interval,
        'final_prediction': final_class,
        'uncertainty_score': uncertainty,
        'all_predictions': predictions
    }

# %%
result = predict_single_image(model, '/content/drive/MyDrive/TA/dt2/panoramik/processed_sehat/33.jpg')

# %%
df_results = predict_batch_images(model, '/content/drive/MyDrive/TA/databasefic/sehat')
visualize_batch_results(df_results)
# Out:
# 🔍 Ditemukan 321 gambar untuk diprediksi...
# 📷 Processing 1/321: 10.jpg
# 📷 Processing 2/321: 104.jpg
# 📷 Processing 3/321: 110.jpg
# 📷 Processing 4/321: 107.jpg
# 📷 Processing 5/321: 101.jpg
# 📷 Processing 6/321: 112.jpg
# 📷 Processing 7/321: 102.jpg
# 📷 Processing 8/321: 116.jpg
# 📷 Processing 9/321: 105.jpg
# 📷 Processing 10/321: 11.jpg
# 📷 Processing 11/321: 114.jpg
# 📷 Processing 12/321: 1.jpg
# 📷 Processing 13/321: 141.jpg
# 📷 Processing 14/321: 140.jpg
# 📷 Processing 15/321: 133.jpg
# 📷 Processing 16/321: 151.jpg
# 📷 Processing 17/321: 150.jpg
# 📷 Processing 18/321: 134.jpg
# 📷 Processing 19/321: 137.jpg
# 📷 Processing 20/321: 146.jpg
# 📷 Processing 21/321: 124.jpg
# 📷 Processing 22/321: 131.jpg
# 📷 Processing 23/321: 126.jpg
# 📷 Processing 24/321: 127.jpg
# 📷 Processing 25/321: 145.jpg
# 📷 Processing 26/321: 143.jpg
# 📷 Processing 27/321: 136.jpg
# 📷 Processing 28/321: 139.jpg
# 📷 Processing 29/321: 149.jpg
# 📷 Processing 30/321: 125.jpg
# 📷 Processing 31/321: 142.jpg
# 📷 Processing 32/321: 132.jpg
# 📷 Processing 33/321: 118.jpg
# 📷 Processing 34/321: 119.jpg
# 📷 Processing 35/321: 174.jpg
# 📷 Processing 36/321: 156.jpg
# 📷 Processing 37/321: 166.jpg
# 📷 Processing 38/321: 176.jpg
# 📷 Processing 39/321: 177.jpg
# 📷 Processing 40/321: 167.jpg
# 📷 Processing 41/321: 184.jpg
# 📷 Processing 42/321: 157.jpg
# 📷 Processing 43/321: 188.jpg
# 📷 Processing 44/321: 185.jpg
# 📷 Processing 45/321: 172.jpg
# 📷 Processing 46/321: 181.jpg
# 📷 Processing 47/321: 183.jpg
# 📷 Processing 48/321: 180.jpg
# 📷 Processing 49/321: 19.jpg
# 📷 Processing 50/321: 189.jpg
# 📷 Processing 51/321: 159.jpg
# 📷 Processing 52/321: 168.jpg
# 📷 Processing 53/321: 162.jpg
# 📷 Processing 54/321: 179.jpg
# 📷 Processing 55/321: 155.jpg
# 📷 Processing 56/321: 229.jpg
# 📷 Processing 57/321: 209.jpg
# 📷 Processing 58/321: 212.jpg
# 📷 Processing 59/321: 206.jpg
# 📷 Processing 60/321: 223.jpg
# 📷 Processing 61/321: 227.jpg
# 📷 Processing 62/321: 194.jpg
# 📷 Processing 63/321: 195.jpg
# 📷 Processing 64/321: 213.jpg
# 📷 Processing 65/321: 23.jpg
# 📷 Processing 66/321: 204.jpg
# 📷 Processing 67/321: 232.jpg
# 📷 Processing 68/321: 199.jpg
# 📷 Processing 69/321: 198.jpg
# 📷 Processing 70/321: 197.jpg
# 📷 Processing 71/321: 215.jpg
# 📷 Processing 72/321: 230.jpg
# 📷 Processing 73/321: 222.jpg
# 📷 Processing 74/321: 231.jpg
# 📷 Processing 75/321: 208.jpg
# 📷 Processing 76/321: 233.jpg
# 📷 Processing 77/321: 218.jpg
# 📷 Processing 78/321: 216.jpg
# 📷 Processing 79/321: 219.jpg
# 📷 Processing 80/321: 250.jpg
# 📷 Processing 81/321: 240.jpg
# 📷 Processing 82/321: 248.jpg
# 📷 Processing 83/321: 249.jpg
# 📷 Processing 84/321: 242.jpg
# 📷 Processing 85/321: 261.jpg
# 📷 Processing 86/321: 258.jpg
# 📷 Processing 87/321: 254.jpg
# 📷 Processing 88/321: 256.jpg
# 📷 Processing 89/321: 266.jpg
# 📷 Processing 90/321: 252.jpg
# 📷 Processing 91/321: 262.jpg
# 📷 Processing 92/321: 26.jpg
# 📷 Processing 93/321: 263.jpg
# 📷 Processing 94/321: 25.jpg
# 📷 Processing 95/321: 239.jpg
# 📷 Processing 96/321: 259.jpg
# 📷 Processing 97/321: 264.jpg
# 📷 Processing 98/321: 253.jpg
# 📷 Processing 99/321: 237.jpg
# 📷 Processing 100/321: 244.jpg
# 📷 Processing 101/321: 274.jpg
# 📷 Processing 102/321: 309.jpg
# 📷 Processing 103/321: 282.jpg
# 📷 Processing 104/321: 299.jpg
# 📷 Processing 105/321: 291.jpg
# 📷 Processing 106/321: 267.jpg
# 📷 Processing 107/321: 280.jpg
# 📷 Processing 108/321: 298.jpg
# 📷 Processing 109/321: 269.jpg
# 📷 Processing 110/321: 281.jpg
# 📷 Processing 111/321: 31.jpg
# 📷 Processing 112/321: 276.jpg
# 📷 Processing 113/321: 268.jpg
# 📷 Processing 114/321: 278.jpg
# 📷 Processing 115/321: 301.jpg
# 📷 Processing 116/321: 287.jpg
# 📷 Processing 117/321: 295.jpg
# 📷 Processing 118/321: 279.jpg
# 📷 Processing 119/321: 294.jpg
# 📷 Processing 120/321: 305.jpg
# 📷 Processing 121/321: 286.jpg
# 📷 Processing 122/321: 271.jpg
# 📷 Processing 123/321: 272.jpg
# 📷 Processing 124/321: 329.jpg
# 📷 Processing 125/321: 343.jpg
# 📷 Processing 126/321: 332.jpg
# 📷 Processing 127/321: 321.jpg
# 📷 Processing 128/321: 33.jpg
# 📷 Processing 129/321: 317.jpg
# 📷 Processing 130/321: 346.jpg
# 📷 Processing 131/321: 313.jpg
# 📷 Processing 132/321: 326.jpg
# 📷 Processing 133/321: 315.jpg
# 📷 Processing 134/321: 32.jpg
# 📷 Processing 135/321: 325.jpg
# 📷 Processing 136/321: 314.jpg
# 📷 Processing 137/321: 324.jpg
# 📷 Processing 138/321: 347.jpg
# 📷 Processing 139/321: 322.jpg
# 📷 Processing 140/321: 337.jpg
# 📷 Processing 141/321: 312.jpg
# 📷 Processing 142/321: 316.jpg
# 📷 Processing 143/321: 342.jpg
# 📷 Processing 144/321: 35.jpg
# 📷 Processing 145/321: 328.jpg
# 📷 Processing 146/321: 345.jpg
# 📷 Processing 147/321: 310.jpg
# 📷 Processing 148/321: 344.jpg
# 📷 Processing 149/321: 34.jpg
# 📷 Processing 150/321: 370.jpg
# 📷 Processing 151/321: 366.jpg
# 📷 Processing 152/321: 392.jpg
# 📷 Processing 153/321: 39.jpg
# 📷 Processing 154/321: 389.jpg
# 📷 Processing 155/321: 383.jpg
# 📷 Processing 156/321: 381.jpg
# 📷 Processing 157/321: 36.jpg
# 📷 Processing 158/321: 373.jpg
# 📷 Processing 159/321: 356.jpg
# 📷 Processing 160/321: 365.jpg
# 📷 Processing 161/321: 380.jpg
# 📷 Processing 162/321: 350.jpg
# 📷 Processing 163/321: 372.jpg
# 📷 Processing 164/321: 391.jpg
# 📷 Processing 165/321: 388.jpg
# 📷 Processing 166/321: 357.jpg
# 📷 Processing 167/321: 371.jpg
# 📷 Processing 168/321: 355.jpg
# 📷 Processing 169/321: 390.jpg
# 📷 Processing 170/321: 379.jpg
# 📷 Processing 171/321: 376.jpg
# 📷 Processing 172/321: 363.jpg
# 📷 Processing 173/321: 378.jpg
# 📷 Processing 174/321: 386.jpg
# 📷 Processing 175/321: 382.jpg
# 📷 Processing 176/321: 410.jpg
# 📷 Processing 177/321: 418.jpg
# 📷 Processing 178/321: 414.jpg
# 📷 Processing 179/321: 393.jpg
# 📷 Processing 180/321: 424.jpg
# 📷 Processing 181/321: 406.jpg
# 📷 Processing 182/321: 421.jpg
# 📷 Processing 183/321: 402.jpg
# 📷 Processing 184/321: 397.jpg
# 📷 Processing 185/321: 407.jpg
# 📷 Processing 186/321: 400.jpg
# 📷 Processing 187/321: 425.jpg
# 📷 Processing 188/321: 430.jpg
# 📷 Processing 189/321: 427.jpg
# 📷 Processing 190/321: 416.jpg
# 📷 Processing 191/321: 468.jpg
# 📷 Processing 192/321: 45.jpg
# 📷 Processing 193/321: 444.jpg
# 📷 Processing 194/321: 463.jpg
# 📷 Processing 195/321: 456.jpg
# 📷 Processing 196/321: 446.jpg
# 📷 Processing 197/321: 439.jpg
# 📷 Processing 198/321: 462.jpg
# 📷 Processing 199/321: 449.jpg
# 📷 Processing 200/321: 472.jpg
# 📷 Processing 201/321: 437.jpg
# 📷 Processing 202/321: 447.jpg
# 📷 Processing 203/321: 440.jpg
# 📷 Processing 204/321: 466.jpg
# 📷 Processing 205/321: 436.jpg
# 📷 Processing 206/321: 454.jpg
# 📷 Processing 207/321: 451.jpg
# 📷 Processing 208/321: 443.jpg
# 📷 Processing 209/321: 465.jpg
# 📷 Processing 210/321: 467.jpg
# 📷 Processing 211/321: 46.jpg
# 📷 Processing 212/321: 452.jpg
# 📷 Processing 213/321: 470.jpg
# 📷 Processing 214/321: 481.jpg
# 📷 Processing 215/321: 509.jpg
# 📷 Processing 216/321: 49.jpg
# 📷 Processing 217/321: 510.jpg
# 📷 Processing 218/321: 473.jpg
# 📷 Processing 219/321: 486.jpg
# 📷 Processing 220/321: 503.jpg
# 📷 Processing 221/321: 488.jpg
# 📷 Processing 222/321: 507.jpg
# 📷 Processing 223/321: 487.jpg
# 📷 Processing 224/321: 496.jpg
# 📷 Processing 225/321: 498.jpg
# 📷 Processing 226/321: 485.jpg
# 📷 Processing 227/321: 497.jpg
# 📷 Processing 228/321: 513.jpg
# 📷 Processing 229/321: 504.jpg
# 📷 Processing 230/321: 51.jpg
# 📷 Processing 231/321: 50.jpg
# 📷 Processing 232/321: 508.jpg
# 📷 Processing 233/321: 494.jpg
# 📷 Processing 234/321: 484.jpg
# 📷 Processing 235/321: 48.jpg
# 📷 Processing 236/321: 478.jpg
# 📷 Processing 237/321: 477.jpg
# 📷 Processing 238/321: 512.jpg
# 📷 Processing 239/321: 528.jpg
# 📷 Processing 240/321: 554.jpg
# 📷 Processing 241/321: 530.jpg
# 📷 Processing 242/321: 519.jpg
# 📷 Processing 243/321: 525.jpg
# 📷 Processing 244/321: 526.jpg
# 📷 Processing 245/321: 54.jpg
# 📷 Processing 246/321: 517.jpg
# 📷 Processing 247/321: 536.jpg
# 📷 Processing 248/321: 546.jpg
# 📷 Processing 249/321: 538.jpg
# 📷 Processing 250/321: 532.jpg
# 📷 Processing 251/321: 542.jpg
# 📷 Processing 252/321: 541.jpg
# 📷 Processing 253/321: 521.jpg
# 📷 Processing 254/321: 544.jpg
# 📷 Processing 255/321: 527.jpg
# 📷 Processing 256/321: 539.jpg
# 📷 Processing 257/321: 53.jpg
# 📷 Processing 258/321: 520.jpg
# 📷 Processing 259/321: 516.jpg
# 📷 Processing 260/321: 52.jpg
# 📷 Processing 261/321: 529.jpg
# 📷 Processing 262/321: 533.jpg
# 📷 Processing 263/321: 531.jpg
# 📷 Processing 264/321: 524.jpg
# 📷 Processing 265/321: 514.jpg
# 📷 Processing 266/321: 518.jpg
# 📷 Processing 267/321: 58.jpg
# 📷 Processing 268/321: 573.jpg
# 📷 Processing 269/321: 559.jpg
# 📷 Processing 270/321: 582.jpg
# 📷 Processing 271/321: 560.jpg
# 📷 Processing 272/321: 558.jpg
# 📷 Processing 273/321: 585.jpg
# 📷 Processing 274/321: 574.jpg
# 📷 Processing 275/321: 567.jpg
# 📷 Processing 276/321: 557.jpg
# 📷 Processing 277/321: 571.jpg
# 📷 Processing 278/321: 555.jpg
# 📷 Processing 279/321: 566.jpg
# 📷 Processing 280/321: 563.jpg
# 📷 Processing 281/321: 570.jpg
# 📷 Processing 282/321: 564.jpg
# 📷 Processing 283/321: 581.jpg
# 📷 Processing 284/321: 568.jpg
# 📷 Processing 285/321: 577.jpg
# 📷 Processing 286/321: 576.jpg
# 📷 Processing 287/321: 57.jpg
# 📷 Processing 288/321: 575.jpg
# 📷 Processing 289/321: 59.jpg
# 📷 Processing 290/321: 60.jpg
# 📷 Processing 291/321: 77.jpg
# 📷 Processing 292/321: 587.jpg
# 📷 Processing 293/321: 62.jpg
# 📷 Processing 294/321: 596.jpg
# 📷 Processing 295/321: 73.jpg
# 📷 Processing 296/321: 597.jpg
# 📷 Processing 297/321: 592.jpg
# 📷 Processing 298/321: 63.jpg
# 📷 Processing 299/321: 70.jpg
# 📷 Processing 300/321: 594.jpg
# 📷 Processing 301/321: 69.jpg
# 📷 Processing 302/321: 64.jpg
# 📷 Processing 303/321: 68.jpg
# 📷 Processing 304/321: 67.jpg
# 📷 Processing 305/321: 61.jpg
# 📷 Processing 306/321: 99.jpg
# 📷 Processing 307/321: 86.jpg
# 📷 Processing 308/321: 92.jpg
# 📷 Processing 309/321: 98.jpg
# 📷 Processing 310/321: 87.jpg
# 📷 Processing 311/321: 83.jpg
# 📷 Processing 312/321: 85.jpg
# 📷 Processing 313/321: 79.jpg
# 📷 Processing 314/321: 95.jpg
# 📷 Processing 315/321: 90.jpg
# 📷 Processing 316/321: 89.jpg
# 📷 Processing 317/321: 94.jpg
# 📷 Processing 318/321: 91.jpg
# 📷 Processing 319/321: 93.jpg
# 📷 Processing 320/321: 80.jpg
# 📷 Processing 321/321: 84.jpg
#
# 📊 RINGKASAN HASIL PREDIKSI:
# Total gambar: 321
# Prediksi Karies: 30
# Prediksi Sehat: 291
# Confidence rata-rata: 68.24%
# 💾 Hasil disimpan ke: /content/drive/MyDrive/TA/dt2/hasil_prediksi_20250623_215348.csv

# %%
advanced_result = advanced_prediction_analysis(model, '/content/drive/MyDrive/TA/dt2/panoramik/processed_sehat/19.jpg')
# Out:
# 🔬 ANALISIS PREDIKSI LANJUTAN:
# 📊 Rata-rata probabilitas karies: 0.629
# 📊 Standard deviasi: 0.089
# 📊 Confidence interval 95%: (0.454, 0.804)
# 📊 Uncertainty score: 0.089
# 🎯 Prediksi final: Karies
# ⚠️  Moderate uncertainty - perlu verifikasi tambahan
